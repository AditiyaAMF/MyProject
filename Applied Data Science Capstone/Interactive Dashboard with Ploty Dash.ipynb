# %%
# !pip install dash==1.19.0  
# !pip install jupyter_dash 
# !pip install --upgrade plotly
# Out:
# Requirement already satisfied: dash==1.19.0 in c:\users\aditi\anaconda3\lib\site-packages (1.19.0)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\aditi\anaconda3\lib\site-packages (from dash==1.19.0) (1.1.2)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\aditi\anaconda3\lib\site-packages (from dash==1.19.0) (1.1.2)
# Requirement already satisfied: flask-compress in c:\users\aditi\anaconda3\lib\site-packages (from dash==1.19.0) (1.10.1)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\aditi\anaconda3\lib\site-packages (from dash==1.19.0) (1.15.0)
# Requirement already satisfied: plotly in c:\users\aditi\anaconda3\lib\site-packages (from dash==1.19.0) (5.5.0)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\aditi\anaconda3\lib\site-packages (from dash==1.19.0) (1.9.0)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\aditi\anaconda3\lib\site-packages (from dash==1.19.0) (4.11.2)
# Requirement already satisfied: future in c:\users\aditi\anaconda3\lib\site-packages (from dash==1.19.0) (0.18.2)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\aditi\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.0.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\aditi\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\aditi\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.11.3)
# Requirement already satisfied: click>=5.1 in c:\users\aditi\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (8.0.3)
# Requirement already satisfied: colorama in c:\users\aditi\anaconda3\lib\site-packages (from click>=5.1->Flask>=1.0.4->dash==1.19.0) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\aditi\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash==1.19.0) (1.1.1)
# Requirement already satisfied: brotli in c:\users\aditi\anaconda3\lib\site-packages (from flask-compress->dash==1.19.0) (1.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\aditi\anaconda3\lib\site-packages (from plotly->dash==1.19.0) (8.0.1)
# Requirement already satisfied: six in c:\users\aditi\anaconda3\lib\site-packages (from plotly->dash==1.19.0) (1.16.0)
# Requirement already satisfied: jupyter_dash in c:\users\aditi\anaconda3\lib\site-packages (0.4.0)
# Requirement already satisfied: ipython in c:\users\aditi\anaconda3\lib\site-packages (from jupyter_dash) (7.29.0)
# Requirement already satisfied: flask in c:\users\aditi\anaconda3\lib\site-packages (from jupyter_dash) (1.1.2)
# Requirement already satisfied: ipykernel in c:\users\aditi\anaconda3\lib\site-packages (from jupyter_dash) (6.4.1)
# Requirement already satisfied: dash in c:\users\aditi\anaconda3\lib\site-packages (from jupyter_dash) (1.19.0)
# Requirement already satisfied: ansi2html in c:\users\aditi\anaconda3\lib\site-packages (from jupyter_dash) (1.7.0)
# Requirement already satisfied: requests in c:\users\aditi\anaconda3\lib\site-packages (from jupyter_dash) (2.26.0)
# Requirement already satisfied: retrying in c:\users\aditi\anaconda3\lib\site-packages (from jupyter_dash) (1.3.3)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\aditi\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: plotly in c:\users\aditi\anaconda3\lib\site-packages (from dash->jupyter_dash) (5.5.0)
# Requirement already satisfied: flask-compress in c:\users\aditi\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.10.1)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\aditi\anaconda3\lib\site-packages (from dash->jupyter_dash) (4.11.2)
# Requirement already satisfied: future in c:\users\aditi\anaconda3\lib\site-packages (from dash->jupyter_dash) (0.18.2)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\aditi\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.1.2)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\aditi\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\aditi\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.11.3)
# Requirement already satisfied: click>=5.1 in c:\users\aditi\anaconda3\lib\site-packages (from flask->jupyter_dash) (8.0.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\aditi\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.0.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\aditi\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: colorama in c:\users\aditi\anaconda3\lib\site-packages (from click>=5.1->flask->jupyter_dash) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\aditi\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask->jupyter_dash) (1.1.1)
# Requirement already satisfied: brotli in c:\users\aditi\anaconda3\lib\site-packages (from flask-compress->dash->jupyter_dash) (1.0.9)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\aditi\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (1.4.1)
# Requirement already satisfied: ipython-genutils in c:\users\aditi\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (0.2.0)
# Requirement already satisfied: traitlets<6.0,>=4.1.0 in c:\users\aditi\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (5.1.0)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\aditi\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1.12)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\aditi\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\aditi\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (0.1.2)
# Requirement already satisfied: backcall in c:\users\aditi\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\aditi\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.18.0)
# Requirement already satisfied: pickleshare in c:\users\aditi\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: pygments in c:\users\aditi\anaconda3\lib\site-packages (from ipython->jupyter_dash) (2.10.0)
# Requirement already satisfied: decorator in c:\users\aditi\anaconda3\lib\site-packages (from ipython->jupyter_dash) (5.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\aditi\anaconda3\lib\site-packages (from ipython->jupyter_dash) (3.0.20)
# Requirement already satisfied: setuptools>=18.5 in c:\users\aditi\anaconda3\lib\site-packages (from ipython->jupyter_dash) (58.0.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\aditi\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\aditi\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter_dash) (4.8.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\aditi\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter_dash) (22.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\aditi\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter_dash) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\aditi\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel->jupyter_dash) (228)
# Requirement already satisfied: wcwidth in c:\users\aditi\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\aditi\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel->jupyter_dash) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\aditi\anaconda3\lib\site-packages (from plotly->dash->jupyter_dash) (8.0.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\aditi\anaconda3\lib\site-packages (from requests->jupyter_dash) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aditi\anaconda3\lib\site-packages (from requests->jupyter_dash) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aditi\anaconda3\lib\site-packages (from requests->jupyter_dash) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\aditi\anaconda3\lib\site-packages (from requests->jupyter_dash) (1.26.7)
# Requirement already satisfied: plotly in c:\users\aditi\anaconda3\lib\site-packages (5.5.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\aditi\anaconda3\lib\site-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in c:\users\aditi\anaconda3\lib\site-packages (from plotly) (1.16.0)

# %%
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
import plotly.express as px


spacex_df = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv')
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()


app = dash.Dash(__name__)
server = app.server

uniquelaunchsites = spacex_df['Launch Site'].unique().tolist()
lsites = []
lsites.append({'label': 'All Sites', 'value': 'All Sites'})
for site in uniquelaunchsites:
 lsites.append({'label': site, 'value': site})



app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),




                                dcc.Dropdown(id='site_dropdown',options=lsites,placeholder='Select a Launch Site here', searchable = True , value = 'All Sites'),
                                html.Br(),


                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),

                                dcc.RangeSlider(
                                    id='payload_slider',
                                    min=0,
                                    max=10000,
                                    step=1000,
                                    marks = {
                                            0: '0 kg',
                                            1000: '1000 kg',
                                            2000: '2000 kg',
                                            3000: '3000 kg',
                                            4000: '4000 kg',
                                            5000: '5000 kg',
                                            6000: '6000 kg',
                                            7000: '7000 kg',
                                            8000: '8000 kg',
                                            9000: '9000 kg',
                                            10000: '10000 kg'
                                    },

                                    value=[min_payload,max_payload]
                                ),

                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),

                                ])

@app.callback(
     Output(component_id='success-pie-chart',component_property='figure'),
     [Input(component_id='site_dropdown',component_property='value')]
)
def update_graph(site_dropdown):
    if (site_dropdown == 'All Sites'):
        df  = spacex_df[spacex_df['class'] == 1]
        fig = px.pie(df, names = 'Launch Site',hole=.3,title = 'Total Success Launches By all sites')
    else:
        df  = spacex_df.loc[spacex_df['Launch Site'] == site_dropdown]
        fig = px.pie(df, names = 'class',hole=.3,title = 'Total Success Launches for site '+site_dropdown)
    return fig

@app.callback(
     Output(component_id='success-payload-scatter-chart',component_property='figure'),
     [Input(component_id='site_dropdown',component_property='value'),Input(component_id="payload_slider", component_property="value")]
)
def update_scattergraph(site_dropdown,payload_slider):
    if site_dropdown == 'All Sites':
        low, high = payload_slider
        df  = spacex_df
        mask = (df['Payload Mass (kg)'] > low) & (df['Payload Mass (kg)'] < high)
        fig = px.scatter(
            df[mask], x="Payload Mass (kg)", y="class",
            color="Booster Version",
            size='Payload Mass (kg)',
            hover_data=['Payload Mass (kg)'])
    else:
        low, high = payload_slider
        df  = spacex_df.loc[spacex_df['Launch Site'] == site_dropdown]
        mask = (df['Payload Mass (kg)'] > low) & (df['Payload Mass (kg)'] < high)
        fig = px.scatter(
            df[mask], x="Payload Mass (kg)", y="class",
            color="Booster Version",
            size='Payload Mass (kg)',
            hover_data=['Payload Mass (kg)'])
    return fig



if __name__ == '__main__':
    app.run_server(debug=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [09/Feb/2022 04:53:32] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Feb/2022 04:53:32] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Feb/2022 04:53:32] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Feb/2022 04:53:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Feb/2022 04:53:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Feb/2022 04:55:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Feb/2022 04:55:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Feb/2022 04:56:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Feb/2022 04:56:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Feb/2022 04:56:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Feb/2022 04:56:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Feb/2022 04:56:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Feb/2022 04:56:19] "POST /_dash-update-component HTTP/1.1" 200 -
